# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Function to define ResNet9 architecture
def ResNet9(input_shape=(224, 224, 3), num_classes=10):
    model = tf.keras.Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(128, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(256, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    return model

IMAGE_SIZE = (224, 224)

# Load images from directories using ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Train',  
    target_size=IMAGE_SIZE,  
    batch_size=32,
    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Test',  
    target_size=IMAGE_SIZE,  
    batch_size=32,
    class_mode='categorical',  
    shuffle=False)  # No need to shuffle for evaluation

# Define ResNet9 model
resnet9_model = ResNet9()

# Compile ResNet9 model
resnet9_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train ResNet9 model
history_resnet9 = resnet9_model.fit(train_generator,
                                    epochs=30)

# Evaluate ResNet9 model on test set
resnet9_loss, resnet9_accuracy = resnet9_model.evaluate(test_generator)
print("ResNet9 Accuracy on Test Set:", resnet9_accuracy)

# Define CNN model
cnn = tf.keras.Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile CNN model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
cnn.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping callback
es = EarlyStopping(monitor='accuracy', mode='max', patience=10, verbose=1, restore_best_weights=True)

# Train CNN model
history_cnn = cnn.fit(train_generator,
                      callbacks=[es], 
                      epochs=30)

# Evaluate CNN model on test set
cnn_loss, cnn_accuracy = cnn.evaluate(test_generator)
print("CNN Accuracy on Test Set:", cnn_accuracy)
# Out:
# Found 680 images belonging to 10 classes.
# Found 294 images belonging to 10 classes.
# c:\Users\anuha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/30
# c:\Users\anuha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.1353 - loss: 5.6320
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.3707 - loss: 1.8075
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.4640 - loss: 1.5954
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.5173 - loss: 1.4551
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5520 - loss: 1.3287
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6190 - loss: 1.0549
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6215 - loss: 1.0599
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6734 - loss: 0.9668
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.7491 - loss: 0.7558
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.7583 - loss: 0.7285
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.7869 - loss: 0.6711
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8408 - loss: 0.4681
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8714 - loss: 0.4292
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.8571 - loss: 0.4206
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8877 - loss: 0.3523
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9390 - loss: 0.2388
# Epoch 17/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9247 - loss: 0.2325
# Epoch 18/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9013 - loss: 0.3166
# Epoch 19/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.8876 - loss: 0.2939
# Epoch 20/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9308 - loss: 0.2735
# Epoch 21/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9430 - loss: 0.2065
# Epoch 22/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9563 - loss: 0.1451
# Epoch 23/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9433 - loss: 0.1660
# Epoch 24/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9346 - loss: 0.1913
# Epoch 25/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9664 - loss: 0.1128
# Epoch 26/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9690 - loss: 0.0958
# Epoch 27/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9502 - loss: 0.1257
# Epoch 28/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9675 - loss: 0.1213
# Epoch 29/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9683 - loss: 0.0813
# Epoch 30/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9686 - loss: 0.0839
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 346ms/step - accuracy: 0.5309 - loss: 3.0437
# ResNet9 Accuracy on Test Set: 0.5952380895614624
# c:\Users\anuha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 428ms/step - accuracy: 0.1058 - loss: 2.3057
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 451ms/step - accuracy: 0.2393 - loss: 2.1722
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 490ms/step - accuracy: 0.2951 - loss: 1.9745
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 509ms/step - accuracy: 0.3304 - loss: 1.8516
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 483ms/step - accuracy: 0.3166 - loss: 1.8345
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 501ms/step - accuracy: 0.3771 - loss: 1.7506
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 568ms/step - accuracy: 0.4105 - loss: 1.6564
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 444ms/step - accuracy: 0.4551 - loss: 1.5303
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 459ms/step - accuracy: 0.5120 - loss: 1.4070
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 441ms/step - accuracy: 0.5179 - loss: 1.3903
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 424ms/step - accuracy: 0.4653 - loss: 1.4697
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 421ms/step - accuracy: 0.5620 - loss: 1.2445
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 438ms/step - accuracy: 0.5612 - loss: 1.2171
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 411ms/step - accuracy: 0.5225 - loss: 1.2794
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 437ms/step - accuracy: 0.6012 - loss: 1.0593
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.5887 - loss: 1.1405
# Epoch 17/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 433ms/step - accuracy: 0.6131 - loss: 1.0772
# Epoch 18/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 416ms/step - accuracy: 0.6137 - loss: 1.0327
# Epoch 19/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 426ms/step - accuracy: 0.6712 - loss: 0.9137
# Epoch 20/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 407ms/step - accuracy: 0.6186 - loss: 1.0464
# Epoch 21/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 436ms/step - accuracy: 0.6318 - loss: 1.0087
# Epoch 22/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 553ms/step - accuracy: 0.6742 - loss: 0.9493
# Epoch 23/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 447ms/step - accuracy: 0.6851 - loss: 0.8748
# Epoch 24/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 648ms/step - accuracy: 0.7414 - loss: 0.8024
# Epoch 25/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.7135 - loss: 0.7597
# Epoch 26/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 571ms/step - accuracy: 0.6974 - loss: 0.8256
# Epoch 27/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 605ms/step - accuracy: 0.7118 - loss: 0.7452
# Epoch 28/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 658ms/step - accuracy: 0.7440 - loss: 0.6662
# Epoch 29/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 585ms/step - accuracy: 0.7736 - loss: 0.6020
# Epoch 30/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 630ms/step - accuracy: 0.7957 - loss: 0.5552
# Restoring model weights from the end of the best epoch: 29.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 269ms/step - accuracy: 0.5123 - loss: 1.7664
# CNN Accuracy on Test Set: 0.5714285969734192

# %%
import os

def count_images(directory):
    count = 0
    for subdir, _, files in os.walk(directory):
        count += len(files)
    return count

train_count = count_images('E:\\Webel\\Flowers\\Train')
val_count = count_images('E:\\Webel\\Flowers\\Test')

print(f"Number of images in training directory: {train_count}")
print(f"Number of images in validation directory: {val_count}")
# Out:
# Number of images in training directory: 700
# Number of images in validation directory: 300

# %%
print("Classes in training set:", train_generator.class_indices)
print("Number of samples in each class (training):")
for class_name, count in train_generator.class_indices.items():
    print(f"{class_name}: {train_generator.samples // len(train_generator.class_indices)}")

print("Classes in validation set:", test_generator.class_indices)
print("Number of samples in each class (validation):")
for class_name, count in test_generator.class_indices.items():
    print(f"{class_name}: {test_generator.samples // len(test_generator.class_indices)}")
# Out:
# Classes in training set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (training):
# Dahlia: 68
# Garbera: 68
# Hibiscus: 68
# Jasmine: 68
# Lotus: 68
# Marigold: 68
# Rose: 68
# Sunflower: 68
# Tulip: 68
# rajnigandha: 68
# Classes in validation set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (validation):
# Dahlia: 29
# Garbera: 29
# Hibiscus: 29
# Jasmine: 29
# Lotus: 29
# Marigold: 29
# Rose: 29
# Sunflower: 29
# Tulip: 29
# rajnigandha: 29

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Define image size and number of classes
IMAGE_SIZE = (224, 224)
NUM_CLASSES = 10

# Ensure a clean state
tf.keras.backend.clear_session()

# Load and preprocess images using ImageDataGenerator with validation split
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    validation_split=0.3  # Use 30% of the data for validation
)

train_generator = train_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Train',
    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    subset='training',  # Use this subset for training
    shuffle=True
)

valid_generator = train_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Train',
    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    subset='validation',  # Use this subset for validation
    shuffle=True
)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Test',
    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Verify the number of images in each subset
print('Classes in training set:', train_generator.class_indices)
print('Number of samples in each class (training):')
for cls, idx in train_generator.class_indices.items():
    print(f'{cls}: {sum(train_generator.classes == idx)}')

print('Classes in validation set:', valid_generator.class_indices)
print('Number of samples in each class (validation):')
for cls, idx in valid_generator.class_indices.items():
    print(f'{cls}: {sum(valid_generator.classes == idx)}')

print('Classes in test set:', test_generator.class_indices)
print('Number of samples in each class (test):')
for cls, idx in test_generator.class_indices.items():
    print(f'{cls}: {sum(test_generator.classes == idx)}')

# Load pre-trained ResNet50 model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='val_accuracy', mode='max', patience=10, verbose=1, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('resnet50_best_model.keras', monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)

# Train the model
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=valid_generator,
    callbacks=[early_stopping, model_checkpoint]
)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"ResNet50 Accuracy on Test Set: {test_accuracy:.4f}")
# Out:
# Found 476 images belonging to 10 classes.
# Found 204 images belonging to 10 classes.
# Found 294 images belonging to 10 classes.
# Classes in training set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (training):
# Dahlia: 49
# Garbera: 49
# Hibiscus: 49
# Jasmine: 49
# Lotus: 49
# Marigold: 49
# Rose: 49
# Sunflower: 49
# Tulip: 49
# rajnigandha: 35
# Classes in validation set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (validation):
# Dahlia: 21
# Garbera: 21
# Hibiscus: 21
# Jasmine: 21
# Lotus: 21
# Marigold: 21
# Rose: 21
# Sunflower: 21
# Tulip: 21
# rajnigandha: 15
# Classes in test set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (test):
# Dahlia: 30
# Garbera: 30
# Hibiscus: 30
# Jasmine: 30
# Lotus: 30
# Marigold: 30
# Rose: 30
# Sunflower: 30
# Tulip: 30
# rajnigandha: 24
# Epoch 1/30
# c:\Users\anuha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 792ms/step - accuracy: 0.1149 - loss: 2.7943
# Epoch 1: val_accuracy improved from -inf to 0.10294, saving model to resnet50_best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.1153 - loss: 2.7924 - val_accuracy: 0.1029 - val_loss: 2.6551
# Epoch 2/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 901ms/step - accuracy: 0.1541 - loss: 2.5123
# Epoch 2: val_accuracy improved from 0.10294 to 0.15686, saving model to resnet50_best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.1543 - loss: 2.5109 - val_accuracy: 0.1569 - val_loss: 2.3525
# Epoch 3/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - accuracy: 0.1281 - loss: 2.4406
# Epoch 3: val_accuracy did not improve from 0.15686
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.1289 - loss: 2.4386 - val_accuracy: 0.1176 - val_loss: 2.3187
# Epoch 4/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 859ms/step - accuracy: 0.1291 - loss: 2.4256
# Epoch 4: val_accuracy did not improve from 0.15686
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1291 - loss: 2.4235 - val_accuracy: 0.1225 - val_loss: 2.2677
# Epoch 5/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.1316 - loss: 2.3023
# Epoch 5: val_accuracy did not improve from 0.15686
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1317 - loss: 2.3019 - val_accuracy: 0.1471 - val_loss: 2.2309
# Epoch 6/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 988ms/step - accuracy: 0.1634 - loss: 2.2575
# Epoch 6: val_accuracy improved from 0.15686 to 0.16176, saving model to resnet50_best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.1625 - loss: 2.2571 - val_accuracy: 0.1618 - val_loss: 2.2417
# Epoch 7/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1477 - loss: 2.2853
# Epoch 7: val_accuracy did not improve from 0.16176
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.1485 - loss: 2.2838 - val_accuracy: 0.1520 - val_loss: 2.2173
# Epoch 8/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1547 - loss: 2.2453
# Epoch 8: val_accuracy did not improve from 0.16176
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.1537 - loss: 2.2450 - val_accuracy: 0.1618 - val_loss: 2.2068
# Epoch 9/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1268 - loss: 2.2556
# Epoch 9: val_accuracy did not improve from 0.16176
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.1269 - loss: 2.2553 - val_accuracy: 0.1324 - val_loss: 2.2380
# Epoch 10/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1191 - loss: 2.2431
# Epoch 10: val_accuracy did not improve from 0.16176
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.1212 - loss: 2.2419 - val_accuracy: 0.1618 - val_loss: 2.2555
# Epoch 11/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1954 - loss: 2.1856
# Epoch 11: val_accuracy did not improve from 0.16176
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.1942 - loss: 2.1871 - val_accuracy: 0.1520 - val_loss: 2.2094
# Epoch 12/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1779 - loss: 2.1988
# Epoch 12: val_accuracy did not improve from 0.16176
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.1766 - loss: 2.2000 - val_accuracy: 0.1422 - val_loss: 2.2251
# Epoch 13/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1581 - loss: 2.2141
# Epoch 13: val_accuracy did not improve from 0.16176
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.1592 - loss: 2.2133 - val_accuracy: 0.1324 - val_loss: 2.2323
# Epoch 14/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1435 - loss: 2.2133
# Epoch 14: val_accuracy improved from 0.16176 to 0.19118, saving model to resnet50_best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.1435 - loss: 2.2134 - val_accuracy: 0.1912 - val_loss: 2.2226
# Epoch 15/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1362 - loss: 2.2066
# Epoch 15: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.1360 - loss: 2.2069 - val_accuracy: 0.1373 - val_loss: 2.1994
# Epoch 16/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1273 - loss: 2.2206
# Epoch 16: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.1275 - loss: 2.2205 - val_accuracy: 0.1520 - val_loss: 2.1926
# Epoch 17/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1502 - loss: 2.1963
# Epoch 17: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.1515 - loss: 2.1962 - val_accuracy: 0.1618 - val_loss: 2.2077
# Epoch 18/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1682 - loss: 2.1548
# Epoch 18: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.1682 - loss: 2.1561 - val_accuracy: 0.1716 - val_loss: 2.2304
# Epoch 19/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1520 - loss: 2.2120
# Epoch 19: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.1530 - loss: 2.2113 - val_accuracy: 0.1471 - val_loss: 2.1893
# Epoch 20/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1900 - loss: 2.1761
# Epoch 20: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.1890 - loss: 2.1778 - val_accuracy: 0.1618 - val_loss: 2.2297
# Epoch 21/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1688 - loss: 2.1880
# Epoch 21: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.1696 - loss: 2.1871 - val_accuracy: 0.1618 - val_loss: 2.2058
# Epoch 22/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1577 - loss: 2.1814
# Epoch 22: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.1581 - loss: 2.1819 - val_accuracy: 0.1667 - val_loss: 2.1983
# Epoch 23/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1468 - loss: 2.1712
# Epoch 23: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.1459 - loss: 2.1730 - val_accuracy: 0.1716 - val_loss: 2.1767
# Epoch 24/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1473 - loss: 2.1799
# Epoch 24: val_accuracy did not improve from 0.19118
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.1480 - loss: 2.1805 - val_accuracy: 0.1863 - val_loss: 2.1987
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.1289 - loss: 2.1352
# ResNet50 Accuracy on Test Set: 0.1769

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Define image size and number of classes
IMAGE_SIZE = (224, 224)
NUM_CLASSES = 10

# Ensure a clean state
tf.keras.backend.clear_session()

# Load and preprocess images using ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2
)

train_generator = train_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Train',
    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Test',
    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Verify the number of images in each subset
print('Classes in training set:', train_generator.class_indices)
print('Number of samples in each class (training):')
for cls, idx in train_generator.class_indices.items():
    print(f'{cls}: {sum(train_generator.classes == idx)}')

print('Classes in test set:', test_generator.class_indices)
print('Number of samples in each class (test):')
for cls, idx in test_generator.class_indices.items():
    print(f'{cls}: {sum(test_generator.classes == idx)}')

# Load pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='accuracy', mode='max', patience=10, verbose=1, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('vgg16_best_model.keras', monitor='accuracy', mode='max', save_best_only=True, verbose=1)

# Train the model
history = model.fit(
    train_generator,
    epochs=30,
    callbacks=[early_stopping, model_checkpoint]
)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"VGG16 Accuracy on Test Set: {test_accuracy:.4f}")
# Out:
# Found 700 images belonging to 10 classes.
# Found 300 images belonging to 10 classes.
# Classes in training set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (training):
# Dahlia: 70
# Garbera: 70
# Hibiscus: 70
# Jasmine: 70
# Lotus: 70
# Marigold: 70
# Rose: 70
# Sunflower: 70
# Tulip: 70
# rajnigandha: 70
# Classes in test set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (test):
# Dahlia: 30
# Garbera: 30
# Hibiscus: 30
# Jasmine: 30
# Lotus: 30
# Marigold: 30
# Rose: 30
# Sunflower: 30
# Tulip: 30
# rajnigandha: 30
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1788 - loss: 2.3085
# Epoch 1: accuracy improved from -inf to 0.25571, saving model to vgg16_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.1821 - loss: 2.3013
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4312 - loss: 1.7616
# Epoch 2: accuracy improved from 0.25571 to 0.47857, saving model to vgg16_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.4332 - loss: 1.7572
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5578 - loss: 1.3547
# Epoch 3: accuracy improved from 0.47857 to 0.58857, saving model to vgg16_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 105s 5s/step - accuracy: 0.5591 - loss: 1.3525
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6340 - loss: 1.1822
# Epoch 4: accuracy improved from 0.58857 to 0.65714, saving model to vgg16_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 115s 5s/step - accuracy: 0.6350 - loss: 1.1806
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6856 - loss: 1.0241
# Epoch 5: accuracy improved from 0.65714 to 0.68714, saving model to vgg16_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 120s 5s/step - accuracy: 0.6856 - loss: 1.0235
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6912 - loss: 0.9431
# Epoch 6: accuracy improved from 0.68714 to 0.70000, saving model to vgg16_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 116s 5s/step - accuracy: 0.6916 - loss: 0.9426
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7173 - loss: 0.8714
# Epoch 7: accuracy improved from 0.70000 to 0.73429, saving model to vgg16_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 115s 5s/step - accuracy: 0

    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Verify the number of images in each subset
print('Classes in training set:', train_generator.class_indices)
print('Number of samples in each class (training):')
for cls, idx in train_generator.class_indices.items():
    print(f'{cls}: {sum(train_generator.classes == idx)}')

print('Classes in test set:', test_generator.class_indices)
print('Number of samples in each class (test):')
for cls, idx in test_generator.class_indices.items():
    print(f'{cls}: {sum(test_generator.classes == idx)}')

# Load pre-trained EfficientNetB0 model
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='accuracy', mode='max', patience=10, verbose=1, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('efficientnetb0_best_model.keras', monitor='accuracy', mode='max', save_best_only=True, verbose=1)

# Train the model
history = model.fit(
    train_generator,
    epochs=30,
    callbacks=[early_stopping, model_checkpoint]
)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"EfficientNetB0 Accuracy on Test Set: {test_accuracy:.4f}")
# Out:
# Found 700 images belonging to 10 classes.
# Found 300 images belonging to 10 classes.
# Classes in training set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (training):
# Dahlia: 70
# Garbera: 70
# Hibiscus: 70
# Jasmine: 70
# Lotus: 70
# Marigold: 70
# Rose: 70
# Sunflower: 70
# Tulip: 70
# rajnigandha: 70
# Classes in test set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (test):
# Dahlia: 30
# Garbera: 30
# Hibiscus: 30
# Jasmine: 30
# Lotus: 30
# Marigold: 30
# Rose: 30
# Sunflower: 30
# Tulip: 30
# rajnigandha: 30
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 14s 1us/step
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0852 - loss: 2.3352
# Epoch 1: accuracy improved from -inf to 0.08286, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.0851 - loss: 2.3352
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 989ms/step - accuracy: 0.1094 - loss: 2.3200
# Epoch 2: accuracy improved from 0.08286 to 0.09143, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1086 - loss: 2.3202
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.0857 - loss: 2.3041
# Epoch 3: accuracy did not improve from 0.09143
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 873ms/step - accuracy: 0.0857 - loss: 2.3045
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.0980 - loss: 2.3162
# Epoch 4: accuracy improved from 0.09143 to 0.09286, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.0978 - loss: 2.3164
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0951 - loss: 2.3111
# Epoch 5: accuracy improved from 0.09286 to 0.09714, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.0952 - loss: 2.3114
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0891 - loss: 2.3124
# Epoch 6: accuracy did not improve from 0.09714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.0894 - loss: 2.3125
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.1204 - loss: 2.3009
# Epoch 7: accuracy improved from 0.09714 to 0.10286, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 914ms/step - accuracy: 0.1196 - loss: 2.3014
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 973ms/step - accuracy: 0.1007 - loss: 2.3083
# Epoch 8: accuracy did not improve from 0.10286
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 974ms/step - accuracy: 0.1000 - loss: 2.3085
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 990ms/step - accuracy: 0.0601 - loss: 2.3174
# Epoch 9: accuracy did not improve from 0.10286
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 991ms/step - accuracy: 0.0607 - loss: 2.3175
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0597 - loss: 2.3180
# Epoch 10: accuracy did not improve from 0.10286
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.0604 - loss: 2.3180
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0964 - loss: 2.3011
# Epoch 11: accuracy did not improve from 0.10286
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.0958 - loss: 2.3013
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0918 - loss: 2.3108
# Epoch 12: accuracy did not improve from 0.10286
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.0918 - loss: 2.3107
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1160 - loss: 2.3012
# Epoch 13: accuracy did not improve from 0.10286
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.1152 - loss: 2.3014
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - accuracy: 0.1155 - loss: 2.3012
# Epoch 14: accuracy improved from 0.10286 to 0.10714, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 908ms/step - accuracy: 0.1151 - loss: 2.3013
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0987 - loss: 2.3080
# Epoch 15: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.0987 - loss: 2.3080
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0915 - loss: 2.3056
# Epoch 16: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.0914 - loss: 2.3058
# Epoch 17/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0922 - loss: 2.3057
# Epoch 17: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.0921 - loss: 2.3058
# Epoch 18/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0885 - loss: 2.3069
# Epoch 18: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.0878 - loss: 2.3069
# Epoch 19/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0813 - loss: 2.3044
# Epoch 19: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.0815 - loss: 2.3044
# Epoch 20/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.0858 - loss: 2.3040
# Epoch 20: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 634ms/step - accuracy: 0.0862 - loss: 2.3040
# Epoch 21/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.0918 - loss: 2.3045
# Epoch 21: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 621ms/step - accuracy: 0.0919 - loss: 2.3046
# Epoch 22/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.0727 - loss: 2.3046
# Epoch 22: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 681ms/step - accuracy: 0.0733 - loss: 2.3046
# Epoch 23/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1002 - loss: 2.3028
# Epoch 23: accuracy did not improve from 0.10714
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.0998 - loss: 2.3027
# Epoch 24/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1178 - loss: 2.3034
# Epoch 24: accuracy improved from 0.10714 to 0.10857, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.1174 - loss: 2.3034
# Epoch 25/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1026 - loss: 2.3063
# Epoch 25: accuracy did not improve from 0.10857
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.1029 - loss: 2.3062
# Epoch 26/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1025 - loss: 2.3041
# Epoch 26: accuracy improved from 0.10857 to 0.11143, saving model to efficientnetb0_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1028 - loss: 2.3040
# Epoch 27/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0864 - loss: 2.3029
# Epoch 27: accuracy did not improve from 0.11143
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.0871 - loss: 2.3028
# Epoch 28/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 986ms/step - accuracy: 0.1105 - loss: 2.3039
# Epoch 28: accuracy did not improve from 0.11143
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 29s 986ms/step - accuracy: 0.1103 - loss: 2.3039
# Epoch 29/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 903ms/step - accuracy: 0.0740 - loss: 2.3030
# Epoch 29: accuracy did not improve from 0.11143
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 25s 903ms/step - accuracy: 0.0741 - loss: 2.3030
# Epoch 30/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 934ms/step - accuracy: 0.0700 - loss: 2.3052
# Epoch 30: accuracy did not improve from 0.11143
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 25s 935ms/step - accuracy: 0.0704 - loss: 2.3052
# Restoring model weights from the end of the best epoch: 26.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 597ms/step - accuracy: 0.0440 - loss: 2.3066
# EfficientNetB0 Accuracy on Test Set: 0.1000

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Define image size and number of classes
IMAGE_SIZE = (299, 299)  # Xception requires 299x299 images
NUM_CLASSES = 10

# Ensure a clean state
tf.keras.backend.clear_session()

# Load and preprocess images using ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2
)

train_generator = train_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Train',
    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'E:\\Webel\\Flowers\\Test',
    target_size=IMAGE_SIZE,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Verify the number of images in each subset
print('Classes in training set:', train_generator.class_indices)
print('Number of samples in each class (training):')
for cls, idx in train_generator.class_indices.items():
    print(f'{cls}: {sum(train_generator.classes == idx)}')

print('Classes in test set:', test_generator.class_indices)
print('Number of samples in each class (test):')
for cls, idx in test_generator.class_indices.items():
    print(f'{cls}: {sum(test_generator.classes == idx)}')

# Load pre-trained Xception model
base_model = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='accuracy', mode='max', patience=10, verbose=1, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('xception_best_model.keras', monitor='accuracy', mode='max', save_best_only=True, verbose=1)

# Train the model
history = model.fit(
    train_generator,
    epochs=30,
    callbacks=[early_stopping, model_checkpoint]
)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Xception Accuracy on Test Set: {test_accuracy:.4f}")
# Out:
# Found 700 images belonging to 10 classes.
# Found 300 images belonging to 10 classes.
# Classes in training set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (training):
# Dahlia: 70
# Garbera: 70
# Hibiscus: 70
# Jasmine: 70
# Lotus: 70
# Marigold: 70
# Rose: 70
# Sunflower: 70
# Tulip: 70
# rajnigandha: 70
# Classes in test set: {'Dahlia': 0, 'Garbera': 1, 'Hibiscus': 2, 'Jasmine': 3, 'Lotus': 4, 'Marigold': 5, 'Rose': 6, 'Sunflower': 7, 'Tulip': 8, 'rajnigandha': 9}
# Number of samples in each class (test):
# Dahlia: 30
# Garbera: 30
# Hibiscus: 30
# Jasmine: 30
# Lotus: 30
# Marigold: 30
# Rose: 30
# Sunflower: 30
# Tulip: 30
# rajnigandha: 30
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 74s 1us/step
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3805 - loss: 1.7575
# Epoch 1: accuracy improved from -inf to 0.57000, saving model to xception_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.3888 - loss: 1.7370
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8301 - loss: 0.5371
# Epoch 2: accuracy improved from 0.57000 to 0.84429, saving model to xception_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.8307 - loss: 0.5348
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9092 - loss: 0.3085
# Epoch 3: accuracy improved from 0.84429 to 0.90143, saving model to xception_best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.